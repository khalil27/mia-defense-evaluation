# %% [markdown]
# # 07 - Final Results Comparison
#
# Ce notebook agrege les sorties des notebooks 03-06.
#
# Important:
# - Les colonnes `auc_reference` viennent de la reference locale de chaque notebook (baseline ou teacher), pas directement du notebook 02.
# - Le notebook 02 sert de baseline unifiee de controle.
# - Pour comparer les defenses entre elles, utiliser prioritairement `delta_auc` (et non la valeur absolue d'une baseline d'un autre notebook).
# - Les notebooks 03-06 sont configures en scenario `black-box attacker strong` pour obtenir une baseline MIA exploitable avant defense.

# %%
import os
import re
from io import StringIO
import nbformat
import pandas as pd

pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 200)

# %%
NOTEBOOKS = {
    'defense1_regularization': '03_standart_with_defense1_regularization.ipynb',
    'defense2_output_limiting': '04_standart_with_defense2_output_limiting.ipynb',
    'defense3_differential_privacy': '05_standart_with_defense3_differential_privacy.ipynb',
    'defense4_distillation': '06_standart_with_defense4_knowledge_distillation.ipynb',
}

def _detect_pipeline_dir():
    cwd = os.path.abspath(os.getcwd())
    if os.path.basename(cwd) == 'transformer_pipeline':
        return cwd
    alt = os.path.join(cwd, 'transformer_pipeline')
    if os.path.isdir(alt):
        return alt
    return cwd

PIPELINE_DIR = _detect_pipeline_dir()
print('PIPELINE_DIR =', PIPELINE_DIR)

def _resolve_nb_path(rel_path):
    p = os.path.join(PIPELINE_DIR, rel_path)
    if os.path.exists(p):
        return p
    p2 = os.path.abspath(rel_path)
    if os.path.exists(p2):
        return p2
    return p

def _postprocess_table(df):
    # Normalize column names and drop pandas index column if present.
    df = df.copy()
    df.columns = [str(c).strip() for c in df.columns]
    if len(df.columns) > 0 and str(df.columns[0]).startswith('Unnamed'):
        col0 = df.columns[0]
        vals = pd.to_numeric(df[col0], errors='coerce')
        if vals.notna().all():
            df = df.drop(columns=[col0])
    for c in df.columns:
        df[c] = pd.to_numeric(df[c], errors='ignore')
    return df

def _read_html_tables_from_cell(cell):
    tables = []
    for out in cell.get('outputs', []):
        data = out.get('data', {})
        html = data.get('text/html')
        if not html:
            continue
        if isinstance(html, list):
            html = ''.join(html)
        try:
            parsed = pd.read_html(StringIO(html))
            for t in parsed:
                tables.append(_postprocess_table(t))
        except Exception:
            pass
    return tables

def _read_text_tables_from_cell(cell):
    tables = []
    for out in cell.get('outputs', []):
        data = out.get('data', {})
        txt = data.get('text/plain')
        if not txt:
            continue
        if isinstance(txt, list):
            txt = ''.join(txt)
        txt = str(txt)
        if '\n' not in txt:
            continue
        try:
            t = pd.read_fwf(StringIO(txt))
            if len(t.columns) >= 2:
                tables.append(_postprocess_table(t))
        except Exception:
            pass
    return tables

def _read_tables_from_cell(cell):
    tables = _read_html_tables_from_cell(cell)
    if tables:
        return tables
    return _read_text_tables_from_cell(cell)

def _extract_test_acc_from_stream(nb):
    pattern = re.compile(r'test_acc(?:_def\d+)?\s*=\s*([0-9]*\.?[0-9]+)')
    for cell in nb.cells:
        if cell.get('cell_type') != 'code':
            continue
        for out in cell.get('outputs', []):
            if out.get('output_type') != 'stream':
                continue
            txt = out.get('text', '')
            if isinstance(txt, list):
                txt = ''.join(txt)
            match = pattern.search(str(txt))
            if match:
                try:
                    return float(match.group(1))
                except Exception:
                    pass
    return None

def _load_notebook(nb_path):
    with open(nb_path, 'r', encoding='utf-8') as f:
        return nbformat.read(f, as_version=4)

def _count_output_cells(nb):
    n = 0
    for cell in nb.cells:
        if cell.get('cell_type') == 'code' and cell.get('outputs'):
            n += 1
    return n

def extract_quick_auc_table_from_nb(nb, robust=False):
    for cell in nb.cells:
        if cell.get('cell_type') != 'code':
            continue
        src = ''.join(cell.get('source', []))
        has_quick = 'Quick AUC summary' in src
        has_robust = 'robust' in src.lower()
        if not has_quick:
            continue
        if robust and not has_robust:
            continue
        if (not robust) and has_robust:
            continue

        tables = _read_tables_from_cell(cell)
        for t in tables:
            cols = [str(c) for c in t.columns]
            if 'attack' in cols and 'delta_auc' in cols:
                return t.copy()
    return None

def extract_model_delta_table_from_nb(nb):
    for cell in nb.cells:
        if cell.get('cell_type') != 'code':
            continue
        tables = _read_tables_from_cell(cell)
        for t in tables:
            cols = [str(c) for c in t.columns]
            if 'delta_test_acc' in cols:
                return t.copy()
    return None
# Out:
# PIPELINE_DIR = c:\Users\khalil\Desktop\stage_pfe\mia-defense-evaluation\transformer_pipeline

# %%
all_quick = {}
all_quick_robust = {}
all_model = {}

for name, rel_path in NOTEBOOKS.items():
    path = _resolve_nb_path(rel_path)
    if not os.path.exists(path):
        print(f'[MISSING] {rel_path} (resolved as: {path})')
        continue

    nb = _load_notebook(path)
    output_cells = _count_output_cells(nb)
    if output_cells == 0:
        print(f'[WARN] {rel_path}: aucune sortie persistÃ©e dans le fichier .ipynb.')
        print('       Ouvre ce notebook, fais Run All puis Save (Ctrl+S), ensuite relance 07.')
        continue

    q = extract_quick_auc_table_from_nb(nb, robust=False)
    q_robust = extract_quick_auc_table_from_nb(nb, robust=True)
    m = extract_model_delta_table_from_nb(nb)

    if q is None:
        print(f'[WARN] Quick AUC table (standard) introuvable dans {rel_path}.')
    else:
        all_quick[name] = q

    if q_robust is None:
        print(f'[WARN] Quick AUC table (robust) introuvable dans {rel_path}.')
    else:
        all_quick_robust[name] = q_robust

    if m is None and name == 'defense2_output_limiting':
        # Fallback: defense2 often logs test_acc in stdout even if mcmp table was not saved.
        test_acc = _extract_test_acc_from_stream(nb)
        if test_acc is not None:
            m = pd.DataFrame([
                {
                    'model': 'Transformer',
                    'test_acc_baseline': float(test_acc),
                    'test_acc_defense2': float(test_acc),
                    'delta_test_acc': 0.0,
                }
            ])
            print(f'[INFO] Defense2 model table reconstructed from stream test_acc={test_acc:.4f}.')

    if m is None:
        print(f'[WARN] Model delta table introuvable dans {rel_path}.')
    else:
        all_model[name] = m

print('Loaded quick tables (standard):', list(all_quick.keys()))
print('Loaded quick tables (robust):', list(all_quick_robust.keys()))
print('Loaded model tables:', list(all_model.keys()))
# Out:
# Loaded quick tables (standard): ['defense1_regularization', 'defense2_output_limiting', 'defense3_differential_privacy', 'defense4_distillation']
# Loaded quick tables (robust): ['defense1_regularization', 'defense2_output_limiting', 'defense3_differential_privacy', 'defense4_distillation']
# Loaded model tables: ['defense1_regularization', 'defense2_output_limiting', 'defense3_differential_privacy', 'defense4_distillation']

# %%
def _pick_col(cols, preferred):
    for p in preferred:
        if p in cols:
            return p
    return None

rows = []
for defense_name, qdf in all_quick.items():
    cols = [str(c) for c in qdf.columns]
    c_baseline = _pick_col(cols, ['auc_mean_baseline', 'auc_baseline', 'auc_teacher'])
    c_defense = _pick_col(cols, ['auc_mean_defense1', 'auc_mean_defense2', 'auc_mean_defense3', 'auc_mean_defense4', 'auc_defense1', 'auc_defense2', 'auc_defense3', 'auc_defense4'])

    for _, r in qdf.iterrows():
        rows.append({
            'defense': defense_name,
            'attack': r['attack'],
            'auc_reference': float(r[c_baseline]) if c_baseline is not None else float('nan'),
            'auc_defense': float(r[c_defense]) if c_defense is not None else float('nan'),
            'delta_auc': float(r['delta_auc']),
        })

comparison_attacks = pd.DataFrame(rows)
if len(comparison_attacks) == 0:
    print('No attack comparison data available yet. Run notebooks 03..06 first.')
else:
    display(comparison_attacks.sort_values(['attack', 'delta_auc']).round(4))
# Out:
#                           defense          attack  auc_reference  auc_defense  delta_auc
# 3        defense2_output_limiting        logistic         0.5070       0.5070     0.0000
# 10          defense4_distillation        logistic         0.5070       0.5100     0.0030
# 1         defense1_regularization        logistic         0.4807       0.5071     0.0264
# 7   defense3_differential_privacy        logistic         0.4807       0.5412     0.0605
# 6   defense3_differential_privacy     shadow_meta         0.6154       0.4917    -0.1237
# 9           defense4_distillation     shadow_meta         0.6070       0.4900    -0.1170
# 0         defense1_regularization     shadow_meta         0.6195       0.5298    -0.0897
# 5        defense2_output_limiting     shadow_meta         0.6070       0.6070     0.0001
# 4        defense2_output_limiting  threshold_loss         0.5070       0.5070     0.0000
# ...

# %%
rows_model = []
for defense_name in NOTEBOOKS.keys():
    if defense_name in all_model and len(all_model[defense_name]) > 0:
        row = all_model[defense_name].iloc[0].to_dict()
    else:
        row = {}
    row['defense'] = defense_name
    rows_model.append(row)

comparison_models = pd.DataFrame(rows_model)
if len(comparison_models) == 0:
    print('No model comparison data available yet. Run notebooks 03..06 first.')
else:
    keep_cols = [
        c for c in [
            'defense',
            'test_acc_baseline',
            'test_acc_teacher',
            'test_acc_defense1',
            'test_acc_defense2',
            'test_acc_defense3',
            'test_acc_student',
            'delta_test_acc',
            'epsilon_target',
        ]
        if c in comparison_models.columns
    ]
    display(comparison_models[keep_cols].round(4))
# Out:
#                          defense  test_acc_baseline  test_acc_teacher  test_acc_defense1  test_acc_defense2  test_acc_defense3  test_acc_student  delta_test_acc
# 0        defense1_regularization             0.9225               NaN             0.9366                NaN                NaN               NaN          0.0141
# 1       defense2_output_limiting             0.9261               NaN                NaN             0.9261                NaN               NaN          0.0000
# 2  defense3_differential_privacy                NaN               NaN                NaN                NaN              0.581               NaN         -0.3415
# 3          defense4_distillation                NaN            0.9261                NaN                NaN                NaN            0.9225         -0.0035

# %%
if len(comparison_attacks) > 0:
    shadow = comparison_attacks[comparison_attacks['attack'] == 'shadow_meta'].copy()
    print('=== Ranking by Shadow Meta delta_auc (lower is better privacy) ===')
    display(shadow.sort_values('delta_auc').round(4))

    # Sanity check: baseline attack strength should be high enough for meaningful defense benchmarking
    if 'auc_reference' in shadow.columns and len(shadow) > 0:
        weak_refs = shadow[shadow['auc_reference'] < 0.55]
        if len(weak_refs) > 0:
            print('[WARN] Certaines references shadow_meta sont < 0.55: interpretation defense a prendre avec prudence.')
            display(weak_refs[['defense', 'auc_reference', 'auc_defense', 'delta_auc']].round(4))
        else:
            print('[OK] References shadow_meta >= 0.55 pour toutes les defenses (benchmark defense pertinent).')

if len(comparison_attacks) > 0:
    print('=== Mean delta_auc per defense (all attacks) ===')
    agg = comparison_attacks.groupby('defense', as_index=False)['delta_auc'].mean().sort_values('delta_auc')
    display(agg.round(4))
# Out:
# === Ranking by Shadow Meta delta_auc (lower is better privacy) ===
#                          defense       attack  auc_reference  auc_defense  delta_auc
# 6  defense3_differential_privacy  shadow_meta         0.6154       0.4917    -0.1237
# 9          defense4_distillation  shadow_meta         0.6070       0.4900    -0.1170
# 0        defense1_regularization  shadow_meta         0.6195       0.5298    -0.0897
# 5       defense2_output_limiting  shadow_meta         0.6070       0.6070     0.0001
# [OK] References shadow_meta >= 0.55 pour toutes les defenses (benchmark defense pertinent).
# === Mean delta_auc per defense (all attacks) ===
#                          defense  delta_auc
# 3          defense4_distillation    -0.0362
# 0        defense1_regularization    -0.0103
# 1       defense2_output_limiting     0.0000
# 2  defense3_differential_privacy     0.0001

# %%
# Robust adaptive comparison (meta + LiRA + boundary)
rows_robust = []
for defense_name, qdf in all_quick_robust.items():
    cols = [str(c) for c in qdf.columns]
    c_baseline = _pick_col(cols, ['auc_mean_baseline', 'auc_baseline', 'auc_teacher'])
    c_defense = _pick_col(cols, ['auc_mean_defense1', 'auc_mean_defense2', 'auc_mean_defense3', 'auc_mean_defense4', 'auc_defense1', 'auc_defense2', 'auc_defense3', 'auc_defense4'])

    for _, r in qdf.iterrows():
        rows_robust.append({
            'defense': defense_name,
            'attack': r['attack'],
            'auc_reference': float(r[c_baseline]) if c_baseline is not None else float('nan'),
            'auc_defense': float(r[c_defense]) if c_defense is not None else float('nan'),
            'delta_auc': float(r['delta_auc']),
        })

comparison_attacks_robust = pd.DataFrame(rows_robust)
if len(comparison_attacks_robust) == 0:
    print('No robust attack comparison data available yet. Run robust cells in notebooks 03..06 first.')
else:
    print('=== Robust adaptive attack comparison ===')
    display(comparison_attacks_robust.sort_values(['attack', 'delta_auc']).round(4))

    if 'shadow_meta' in comparison_attacks_robust['attack'].values:
        print('=== Robust ranking by shadow_meta delta_auc (lower is better privacy) ===')
        shadow_robust = comparison_attacks_robust[comparison_attacks_robust['attack'] == 'shadow_meta'].copy()
        display(shadow_robust.sort_values('delta_auc').round(4))
# Out:
# === Robust adaptive attack comparison ===
#                          defense       attack  auc_reference  auc_defense  delta_auc
# 2  defense3_differential_privacy  shadow_meta         0.6643       0.5376    -0.1267
# 0        defense1_regularization  shadow_meta         0.6557       0.5337    -0.1220
# 3          defense4_distillation  shadow_meta         0.5978       0.4958    -0.1020
# 1       defense2_output_limiting  shadow_meta         0.5978       0.5939    -0.0039
# === Robust ranking by shadow_meta delta_auc (lower is better privacy) ===
#                          defense       attack  auc_reference  auc_defense  delta_auc
# 2  defense3_differential_privacy  shadow_meta         0.6643       0.5376    -0.1267
# 0        defense1_regularization  shadow_meta         0.6557       0.5337    -0.1220
# 3          defense4_distillation  shadow_meta         0.5978       0.4958    -0.1020
# 1       defense2_output_limiting  shadow_meta         0.5978       0.5939    -0.0039

# %%
# IMPROVED ANALYSIS: Check actual columns and extract results
print("="*80)
print("COMPREHENSIVE RESULTS ANALYSIS: NOTEBOOKS 02-07")
print("="*80)

# First, let's see what columns are actually in the dataframes
if all_quick_robust:
    sample_df = next(iter(all_quick_robust.values()))
    print(f"\nActual columns in robust tables:")
    for col in sample_df.columns:
        print(f"  - '{col}'")
    print(f"\nSample data from defense1_regularization (robust):")
    print(sample_df[sample_df['attack'] == 'shadow_meta'].head())

print("\n" + "="*80)
print("### ROBUST ADAPTIVE ATTACK RESULTS (shadow_meta) - BEST INDICATOR OF DEFENSE ###\n")

best_privacy = None
best_delta = 0
worst_privacy = None
worst_delta = 0

for defense_name, df_robust in sorted(all_quick_robust.items()):
    df_f = df_robust[df_robust['attack'] == 'shadow_meta'].copy()
    if len(df_f) > 0:
        row = df_f.iloc[0]
        delta = row['delta_auc']
        ref = row.get('auc_reference', row.get('AUC_reference', row.get('auc_reference_robust', 0)))
        def_ = row.get('auc_defense', row.get('AUC_defense', row.get('auc_defense_robust', 0)))
        
        def_display = defense_name.replace('defense', 'D').replace('_', ' ').title()
        print(f"{def_display:35s} â†’ Î”_AUC = {delta:+.4f}")
        
        if delta < best_delta or best_privacy is None:
            best_delta = delta
            best_privacy = def_display
        if delta > worst_delta:
            worst_delta = delta
            worst_privacy = def_display

print(f"\n{'='*80}")
print("### RANKING (Lower delta_auc = Better Privacy) ###\n")
deltas_by_defense = []
for defense_name, df_robust in all_quick_robust.items():
    df_f = df_robust[df_robust['attack'] == 'shadow_meta'].copy()
    if len(df_f) > 0:
        delta = df_f.iloc[0]['delta_auc']
        deltas_by_defense.append((defense_name.replace('defense', 'D').replace('_', ' ').title(), delta))

deltas_by_defense.sort(key=lambda x: x[1])
for rank, (name, delta) in enumerate(deltas_by_defense, 1):
    print(f"{rank}. {name:35s} â†’ {delta:+.4f}")

if best_privacy:
    print(f"\nâœ“ BEST DEFENSE: {best_privacy} (Î” = {best_delta:+.4f})")
    print(f"âœ— WEAKEST: {worst_privacy} (Î” = {worst_delta:+.4f})")
    print(f"\nInterpretation:")
    print(f"  - Negative delta means the defense REDUCES attack effectiveness")
    print(f"  - More negative = stronger defense reduction")
    print(f"  - Difference: {abs(best_delta - worst_delta):.4f} (magnitude of privacy improvement)")
# Out:
# ...
# COMPREHENSIVE RESULTS ANALYSIS: NOTEBOOKS 02-07
# ...
#
# Actual columns in robust tables:
#   - 'attack'
#   - 'auc_mean_baseline'
#   - 'auc_mean_defense1'
#   - 'delta_auc'
#
# Sample data from defense1_regularization (robust):
#         attack  auc_mean_baseline  auc_mean_defense1  delta_auc
# 0  shadow_meta             0.6557             0.5337     -0.122
#
# ...
# ### ROBUST ADAPTIVE ATTACK RESULTS (shadow_meta) - BEST INDICATOR OF DEFENSE ###
#
# D1 Regularization                   â†’ Î”_AUC = -0.1220
# D2 Output Limiting                  â†’ Î”_AUC = -0.0039
# D3 Differential Privacy             â†’ Î”_AUC = -0.1267
# D4 Distillation                     â†’ Î”_AUC = -0.1020
#
# ...
# ### RANKING (Lower delta_auc = Better Privacy) ###
#
# 1. D3 Differential Privacy             â†’ -0.1267
# 2. D1 Regularization                   â†’ -0.1220
# 3. D4 Distillation                     â†’ -0.1020
# 4. D2 Output Limiting                  â†’ -0.0039
#
# ...

# %%
# EXTENDED ANALYSIS: Compare standard vs robust attacks + model utility
print("\n" + "="*80)
print("### COMPARISON: STANDARD ATTACKS vs ROBUST ADAPTIVE ###\n")

print("Standard Attacks (meta, lira, ref-based):")
for defense_name, df_quick in sorted(all_quick.items()):
    df_meta = df_quick[df_quick['attack'] == 'shadow_meta'].copy()
    if len(df_meta) > 0:
        cols = list(df_meta.columns)
        delta_std = df_meta.iloc[0]['delta_auc']
        def_name = defense_name.replace('defense', 'D').replace('_', ' ').title()
        print(f"  {def_name:35s} â†’ {delta_std:+.4f}")

print("\nRobust Adaptive Attack:")
for defense_name, df_robust in sorted(all_quick_robust.items()):
    df_meta = df_robust[df_robust['attack'] == 'shadow_meta'].copy()
    if len(df_meta) > 0:
        delta_rob = df_meta.iloc[0]['delta_auc']
        def_name = defense_name.replace('defense', 'D').replace('_', ' ').title()
        print(f"  {def_name:35s} â†’ {delta_rob:+.4f}")

print("\n" + "="*80)
print("### MODEL UTILITY ANALYSIS ###\n")

if all_model:
    print("Model columns available in all_model:")
    for defense_name, df_model in list(all_model.items())[:1]:
        print(f"  Columns: {list(df_model.columns)}")
    print()
    
    for defense_name, df_model in sorted(all_model.items()):
        def_name = defense_name.replace('defense', 'D').replace('_', ' ').title()
        print(f"{def_name}:")
        print(df_model.to_string(index=False))
        print()
else:
    print("[No model data available]")

print("="*80)
print("### FINAL SUMMARY FOR RESEARCH PUBLICATION ###\n")
print("Key Metrics (Robust Adaptive Attack - most realistic threat):")
print()
print("  Defense Strategy      | Privacy Gain (Î”_AUC) | Ranking | Effectiveness")
print("  " + "-"*70)

results_raw = []
for defense_name, df_robust in all_quick_robust.items():
    df_f = df_robust[df_robust['attack'] == 'shadow_meta'].copy()
    if len(df_f) > 0:
        row = df_f.iloc[0]
        delta = row['delta_auc']
        base = row['auc_mean_baseline']
        # Try to get defense column
        def_col = [c for c in row.index if 'defense' in c.lower() and 'mean' in c.lower()]
        def_ = row[def_col[0]] if def_col else 0.0
        
        results_raw.append({
            'name': defense_name,
            'delta': delta,
            'baseline': base,
            'defended': def_,
        })

results_raw.sort(key=lambda x: x['delta'])

for rank, r in enumerate(results_raw, 1):
    def_name = r['name'].replace('defense', '').replace('_', ' ').title()
    effectiveness = "Strong" if r['delta'] <= -0.12 else ("Moderate" if r['delta'] <= -0.10 else "Weak")
    print(f"  {def_name:20s} | {r['delta']:+.4f}          | #{rank}      | {effectiveness}")
    print(f"    â”œâ”€ Baseline AUC: {r['baseline']:.4f} â†’ Defended: {r['defended']:.4f}")

print("\n" + "="*80)
# Out:
# ...
# ### COMPARISON: STANDARD ATTACKS vs ROBUST ADAPTIVE ###
#
# Standard Attacks (meta, lira, ref-based):
#   D1 Regularization                   â†’ -0.0897
#   D2 Output Limiting                  â†’ +0.0001
#   D3 Differential Privacy             â†’ -0.1237
#   D4 Distillation                     â†’ -0.1170
#
# Robust Adaptive Attack:
#   D1 Regularization                   â†’ -0.1220
#   D2 Output Limiting                  â†’ -0.0039
#   D3 Differential Privacy             â†’ -0.1267
#   D4 Distillation                     â†’ -0.1020
#
# ...
# ### MODEL UTILITY ANALYSIS ###
#
# Model columns available in all_model:
#   Columns: ['model', 'test_acc_baseline', 'test_acc_defense1', 'delta_test_acc']
#
# D1 Regularization:
#       model  test_acc_baseline  test_acc_defense1  delta_test_acc
# Transformer             0.9225             0.9366          0.0141
#
# D2 Output Limiting:
#       model  test_acc_baseline  test_acc_defense2  delta_test_acc
# ...

# %%
# Comparison against notebook 02 unified baseline
BASELINE_NB = _resolve_nb_path('02_standart_baseline_and_attacks.ipynb')

if not os.path.exists(BASELINE_NB):
    print(f'[MISSING] Baseline notebook not found: {BASELINE_NB}')
else:
    nb02 = _load_notebook(BASELINE_NB)
    baseline_tables = []
    for cell in nb02.cells:
        if cell.get('cell_type') != 'code':
            continue
        baseline_tables.extend(_read_tables_from_cell(cell))

    auc_tables = []
    for t in baseline_tables:
        cols = [str(c) for c in t.columns]
        if 'attack' in cols and 'auc_mean' in cols:
            tt = t.copy()
            tt['attack'] = tt['attack'].astype(str)
            auc_tables.append(tt)

    baseline_std_auc = float('nan')
    baseline_rob_auc = float('nan')

    std_candidates = [t for t in auc_tables if len(t) >= 2 and 'shadow_meta' in set(t['attack'])]
    if std_candidates:
        std_table = max(std_candidates, key=lambda x: len(x.columns))
        baseline_std_auc = float(std_table.loc[std_table['attack'] == 'shadow_meta', 'auc_mean'].iloc[0])

    rob_candidates = [t for t in auc_tables if len(t) == 1 and 'shadow_meta' in set(t['attack'])]
    if rob_candidates:
        rob_table = max(rob_candidates, key=lambda x: len(x.columns))
        baseline_rob_auc = float(rob_table.loc[rob_table['attack'] == 'shadow_meta', 'auc_mean'].iloc[0])

    print('=== Unified baseline from notebook 02 (shadow_meta) ===')
    print(f'standard baseline auc_mean = {baseline_std_auc:.4f}')
    print(f'robust   baseline auc_mean = {baseline_rob_auc:.4f}')

    # Standard comparison vs notebook 02 baseline
    print('\n=== Defense comparison vs notebook 02 baseline (STANDARD) ===')
    if len(comparison_attacks) == 0 or pd.isna(baseline_std_auc):
        print('Not enough data to compute standard baseline comparison.')
    else:
        std_shadow = comparison_attacks[comparison_attacks['attack'] == 'shadow_meta'].copy()
        if len(std_shadow) == 0:
            print('No shadow_meta rows in standard comparison table.')
        else:
            std_shadow['baseline_02_auc'] = baseline_std_auc
            std_shadow['auc_gain_vs_02'] = std_shadow['auc_defense'] - baseline_std_auc
            std_shadow = std_shadow[['defense', 'baseline_02_auc', 'auc_defense', 'auc_gain_vs_02', 'delta_auc']]
            std_shadow = std_shadow.sort_values('auc_gain_vs_02')
            display(std_shadow.round(4))

    # Robust comparison vs notebook 02 baseline
    print('\n=== Defense comparison vs notebook 02 baseline (ROBUST) ===')
    if len(comparison_attacks_robust) == 0 or pd.isna(baseline_rob_auc):
        print('Not enough data to compute robust baseline comparison.')
    else:
        rob_shadow = comparison_attacks_robust[comparison_attacks_robust['attack'] == 'shadow_meta'].copy()
        if len(rob_shadow) == 0:
            print('No shadow_meta rows in robust comparison table.')
        else:
            rob_shadow['baseline_02_auc'] = baseline_rob_auc
            rob_shadow['auc_gain_vs_02'] = rob_shadow['auc_defense'] - baseline_rob_auc
            rob_shadow = rob_shadow[['defense', 'baseline_02_auc', 'auc_defense', 'auc_gain_vs_02', 'delta_auc']]
            rob_shadow = rob_shadow.sort_values('auc_gain_vs_02')
            display(rob_shadow.round(4))
# Out:
# === Unified baseline from notebook 02 (shadow_meta) ===
# standard baseline auc_mean = 0.5715
# robust   baseline auc_mean = 0.5734
#
# === Defense comparison vs notebook 02 baseline (STANDARD) ===
#                          defense  baseline_02_auc  auc_defense  auc_gain_vs_02  delta_auc
# 9          defense4_distillation           0.5715       0.4900         -0.0815    -0.1170
# 6  defense3_differential_privacy           0.5715       0.4917         -0.0798    -0.1237
# 0        defense1_regularization           0.5715       0.5298         -0.0417    -0.0897
# 5       defense2_output_limiting           0.5715       0.6070          0.0355     0.0001
# === Defense comparison vs notebook 02 baseline (ROBUST) ===
#                          defense  baseline_02_auc  auc_defense  auc_gain_vs_02  delta_auc
# 3          defense4_distillation           0.5734       0.4958         -0.0776    -0.1020
# 0        defense1_regularization           0.5734       0.5337         -0.0397    -0.1220
# ...
